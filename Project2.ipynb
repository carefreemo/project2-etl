# %%
# Install sqlalchemy 

# !pip install psycopg2

# %%
# 1. Import libraries

from sqlalchemy import create_engine as ce
import pandas as pd
import numpy as np

# %%
# 2. Import and read the National University Rankings csv file

Universities = "NationalUniversitiesRankingsFinal.csv"

Universities = pd.read_csv (Universities)
Universities
# Out:
#                                          Name             Location  Rank  \
# 0                        Princeton University        Princeton, NJ     1
# 1                          Harvard University        Cambridge, MA     2
# 2                       University of Chicago          Chicago, IL     3
# 3                             Yale University        New Haven, CT     3
# 4                         Columbia University         New York, NY     5
# ..                                        ...                  ...   ...
# 226    University of Massachusetts--Dartmouth  North Dartmouth, MA   220
# 227         University of Missouri--St. Louis        St. Louis, MO   220
# 228  University of North Carolina--Greensboro       Greensboro, NC   220
# 229        University of Southern Mississippi      Hattiesburg, MS   220
# 230                     Utah State University            Logan, UT   220
#
#                                            Description Tuition and fees  \
# ...

# %%
# 3. Use the head function to refer school rankings (we are maininly looking for top 10 unis and to review the data)

Universities.head(15)
# Out:
#                                      Name          Location  Rank  \
# 0                    Princeton University     Princeton, NJ     1
# 1                      Harvard University     Cambridge, MA     2
# 2                   University of Chicago       Chicago, IL     3
# 3                         Yale University     New Haven, CT     3
# 4                     Columbia University      New York, NY     5
# 5                     Stanford University      Stanford, CA     5
# 6   Massachusetts Institute of Technology     Cambridge, MA     7
# 7                         Duke University        Durham, NC     8
# 8              University of Pennsylvania  Philadelphia, PA     8
# 9                Johns Hopkins University     Baltimore, MD    10
# 10                      Dartmouth College       Hanover, NH    11
# 11     California Institute of Technology      Pasadena, CA    12
# 12                Northwestern University      Evanston, IL    12
# ...

# %%
# 4. Use the drop function to drop any university that is not a top 10 school

Universities.drop(Universities.index[10:231], inplace = True)
Universities
# Out:
#                                     Name          Location  Rank  \
# 0                   Princeton University     Princeton, NJ     1
# 1                     Harvard University     Cambridge, MA     2
# 2                  University of Chicago       Chicago, IL     3
# 3                        Yale University     New Haven, CT     3
# 4                    Columbia University      New York, NY     5
# 5                    Stanford University      Stanford, CA     5
# 6  Massachusetts Institute of Technology     Cambridge, MA     7
# 7                        Duke University        Durham, NC     8
# 8             University of Pennsylvania  Philadelphia, PA     8
# 9               Johns Hopkins University     Baltimore, MD    10
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# ...

# %%
# 5. Use the Data Frame function to create a data frame for the new University data set

UniversitiesClean = pd.DataFrame(Universities[["Name","Location","Rank"]])
UniversitiesClean
# Out:
#                                     Name          Location  Rank
# 0                   Princeton University     Princeton, NJ     1
# 1                     Harvard University     Cambridge, MA     2
# 2                  University of Chicago       Chicago, IL     3
# 3                        Yale University     New Haven, CT     3
# 4                    Columbia University      New York, NY     5
# 5                    Stanford University      Stanford, CA     5
# 6  Massachusetts Institute of Technology     Cambridge, MA     7
# 7                        Duke University        Durham, NC     8
# 8             University of Pennsylvania  Philadelphia, PA     8
# 9               Johns Hopkins University     Baltimore, MD    10

# %%
# 6. Use the rename function to rename the 'Name' column to 'college'

UniversitiesClean.rename(columns={'Name': 'college'}, inplace=True)
UniversitiesClean
# Out:
#                                  college          Location  Rank
# 0                   Princeton University     Princeton, NJ     1
# 1                     Harvard University     Cambridge, MA     2
# 2                  University of Chicago       Chicago, IL     3
# 3                        Yale University     New Haven, CT     3
# 4                    Columbia University      New York, NY     5
# 5                    Stanford University      Stanford, CA     5
# 6  Massachusetts Institute of Technology     Cambridge, MA     7
# 7                        Duke University        Durham, NC     8
# 8             University of Pennsylvania  Philadelphia, PA     8
# 9               Johns Hopkins University     Baltimore, MD    10

# %%
#7. Import and Read the Players csv file 

Players = "PlayersFinal.csv"

Players = pd.read_csv (Players)
Players
# Out:
#             _id  birthDate                      birthPlace  career_AST  \
# 0     abdelal01  24-Jun-68                    Cairo, Egypt         0.3
# 1     abdulza01   7-Apr-46              Brooklyn, New York         1.2
# 2     abdulka01  16-Apr-47              New York, New York         3.6
# 3     abdulma02   9-Mar-69           Gulfport, Mississippi         3.5
# 4     abdulta01   3-Nov-74          Maisons Alfort, France         1.1
# ...         ...        ...                             ...         ...
# 4680  zizican01   4-Jan-97                  Split, Croatia         0.6
# 4681   zoetji01  20-Dec-53                Uxbridge, Canada         0.1
# 4682   zopfbi01   7-Jun-48                             NaN         1.4
# 4683  zubaciv01  18-Mar-97  Mostar, Bosnia and Herzegovina         0.8
# 4684  zunicma01  19-Dec-19            Renton, Pennsylvania         0.9
#
#      career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# ...

# %%
# 8. Use the DataFrame function to create a data frame for the Players file

PlayersClean = pd.DataFrame(Players[['_id', 'name', 'birthDate', 'birthPlace', 'college', 'draft_pick',
       'draft_round', 'draft_team', 'draft_year', 'highSchool', 'position', 'shoots', 'weight']])
PlayersClean
# Out:
#             _id                 name  birthDate  \
# 0     abdelal01       Alaa Abdelnaby  24-Jun-68
# 1     abdulza01      Zaid Abdul-Aziz   7-Apr-46
# 2     abdulka01  Kareem Abdul-Jabbar  16-Apr-47
# 3     abdulma02   Mahmoud Abdul-Rauf   9-Mar-69
# 4     abdulta01    Tariq Abdul-Wahad   3-Nov-74
# ...         ...                  ...        ...
# 4680  zizican01           Ante Zizic   4-Jan-97
# 4681   zoetji01             Jim Zoet  20-Dec-53
# 4682   zopfbi01            Bill Zopf   7-Jun-48
# 4683  zubaciv01          Ivica Zubac  18-Mar-97
# 4684  zunicma01           Matt Zunic  19-Dec-19
#
#                           birthPlace  \
# 0                       Cairo, Egypt
# 1                 Brooklyn, New York
# 2                 New York, New York
# 3              Gulfport, Mississippi
# 4             Maisons Alfort, France
# ...                              ...
# 4680                  Split, Croatia
# 4681                Uxbridge, Canada
# 4682                             NaN
# ...

# %%
# 9. Use the dropna function to drop any row that has NAn in the 'college' column

PlayersClean.dropna(subset=['college'])
# Out:
#             _id                 name  birthDate                 birthPlace  \
# 0     abdelal01       Alaa Abdelnaby  24-Jun-68               Cairo, Egypt
# 1     abdulza01      Zaid Abdul-Aziz   7-Apr-46         Brooklyn, New York
# 2     abdulka01  Kareem Abdul-Jabbar  16-Apr-47         New York, New York
# 3     abdulma02   Mahmoud Abdul-Rauf   9-Mar-69      Gulfport, Mississippi
# 4     abdulta01    Tariq Abdul-Wahad   3-Nov-74     Maisons Alfort, France
# ...         ...                  ...        ...                        ...
# 4677  zimmede01    Derrick Zimmerman   2-Dec-81          Monroe, Louisiana
# 4678  zimmest01    Stephen Zimmerman   9-Sep-96  Hendersonville, Tennessee
# 4681   zoetji01             Jim Zoet  20-Dec-53           Uxbridge, Canada
# 4682   zopfbi01            Bill Zopf   7-Jun-48                        NaN
# 4684  zunicma01           Matt Zunic  19-Dec-19       Renton, Pennsylvania
#
# ...

# %%
# 10. Use the str.contains function to find look iny  the 'college' column and replace any cell that contains 
#     'Stanford University' with 'Standford University'

PlayersClean[PlayersClean['college'].str.contains('Stanford University', na=False)]
# Out:
#             _id              name  birthDate                   birthPlace  \
# 278   bedelbo01        Bob Bedell  26-Jun-44      Los Angeles, California
# 403   borchcu01  Curtis Borchardt  13-Sep-80            Buffalo, New York
# 458   bratzmi01        Mike Bratz  17-Oct-55           Lompoc, California
# 500   brownan02     Anthony Brown  10-Oct-92       Bellflower, California
# 598   butlegr01       Greg Butler  11-Mar-66        Inglewood, California
# 719   childjo01    Josh Childress  20-Jun-83      Harbor City, California
# 775   collija03    Jarron Collins   2-Dec-78       Northridge, California
# 776   collija04     Jason Collins   2-Dec-78       Northridge, California
# 906   dallmho01     Howie Dallmar  24-May-22    San Francisco, California
# 1282  fieldla01     Landry Fields  27-Jun-88       Long Beach, California
# 1702  harriar01        Art Harris  13-Jan-47                          NaN
# 1916  huestjo01      Josh Huestis  19-Dec-91               Webster, Texas
# ...

# %%
# 11. Use the str function to find look iny  the 'college' column and replace any cell that contains 
#     'Duke University' with 'Duke University'


PlayersClean[PlayersClean['college'].str.contains('Duke University', na=False)]
# Out:
#             _id              name  birthDate               birthPlace  \
# 0     abdelal01    Alaa Abdelnaby  24-Jun-68             Cairo, Egypt
# 39    alarima01       Mark Alarie  11-Dec-63         Phoenix, Arizona
# 55    allengr01     Grayson Allen   8-Oct-95    Jacksonville, Florida
# 135   armstta01    Tate Armstrong   5-Oct-55        Moultrie, Georgia
# 159   averywi01     William Avery   8-Aug-79         Augusta, Georgia
# ...         ...               ...        ...                      ...
# 4264  vergabo01         Bob Verga   7-Sep-45      Neptune, New Jersey
# 4500  williel01   Elliot Williams  20-Jun-89       Memphis, Tennessee
# 4513  willija03      Jay Williams  10-Sep-81   Plainfield, New Jersey
# 4549  willish02  Shelden Williams  21-Oct-83  Oklahoma City, Oklahoma
# 4589  winslju01   Justise Winslow  26-Mar-96           Houston, Texas
#
#                                      college    draft_pick draft_round  \
# ...

# %%
# 12. Use the str function to find look iny  the 'college' column and replace any cell that contains 
#     'University of Pennsylvania' with 'University of Pennsylvania'

PlayersClean[PlayersClean['college'].str.contains('University of Pennsylvania', na=False)]
# Out:
#             _id                name  birthDate                  birthPlace  \
# 57    allenje01        Jerome Allen  28-Jan-73  Philadelphia, Pennsylvania
# 275    becker01          Ernie Beck  11-Dec-31  Philadelphia, Pennsylvania
# 329   bigelbo01         Bob Bigelow  26-Dec-53       Boston, Massachusetts
# 393   bookebu01        Butch Booker  20-Jul-45                         NaN
# 422   bowmair01          Ira Bowman  11-Jun-73          Newark, New Jersey
# 528   brownmy01         Myron Brown   3-Nov-69  McKees Rocks, Pennsylvania
# 625   calhoco01       Corky Calhoun   1-Nov-50          Waukegan, Illinois
# 785   colonjo01          Joe Colone  23-Jan-24       Berwick, Pennsylvania
# 874   crossch01       Chink Crossin   4-Jul-23       Luzerne, Pennsylvania
# 1284  fillmgr01       Greg Fillmore   7-Mar-47  Philadelphia, Pennsylvania
# 1662  hankiph01      Phil Hankinson  26-Jul-51            Augusta, Georgia
# ...

# %%
PlayersClean.columns
# Out:
# Index(['_id', 'name', 'birthDate', 'birthPlace', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'highSchool', 'position',
#        'shoots', 'weight'],
#       dtype='object')

# %%
# 13. Use the merge function to perform a right join (PlayersClean (left) and UniversitiesClean (right))

Combineddf=pd.merge(PlayersClean,UniversitiesClean,on="college", how = 'right')
Combineddf.head()
# Out:
#          _id            name  birthDate                        birthPlace  \
# 0  bradlbi01    Bill Bradley  28-Jul-43            Crystal City, Missouri
# 1  goodrst01  Steve Goodrich  18-Mar-76        Philadelphia, Pennsylvania
# 2   hillar01     Armond Hill  31-Mar-53                Brooklyn, New York
# 3  hummejo01     John Hummer   4-May-48  Washington, District of Columbia
# 4  kearnmi01     Mike Kearns  18-Jun-29               Trenton, New Jersey
#
#                 college    draft_pick     draft_round             draft_team  \
# 0  Princeton University           NaN  1965 NBA Draft        New York Knicks
# 1  Princeton University           NaN             NaN                    NaN
# 2  Princeton University   9th overall       1st round          Atlanta Hawks
# 3  Princeton University  15th overall       1st round         Buffalo Braves
# 4  Princeton University  48th overall       5th round  Philadelphia Warriors
#
# ...

# %%
# Connect to PosgreSQL
pg_engine = ce("postgresql://postgres:postgres@localhost:5432/NBA_DB")

# %%
#pg_engine.table_names()

# %%
# Create University Table in SQL

UniversitiesClean.to_sql(name='UniversitiesTable', con=pg_engine, if_exists='append', index=False)

# %%
# Create Players Table in SQL

PlayersClean.to_sql(name='PlayersTable', con=pg_engine, if_exists='append', index=False)
